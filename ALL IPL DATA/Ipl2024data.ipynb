# %% [markdown]
# Ipl 2024 model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd
data=pd.read_csv("ipl_matches2008-2024.csv")
data
# Out:
#            id  season        city        date   match_type  player_of_match  \
# 0      335982    2008   Bangalore  2008-04-18       League      BB McCullum
# 1      335983    2008  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984    2008       Delhi  2008-04-19       League      MF Maharoof
# 3      335985    2008      Mumbai  2008-04-20       League       MV Boucher
# 4      335986    2008     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...     ...         ...         ...          ...              ...
# 1090  1426307    2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309    2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310    2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311    2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312    2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
data.shape
# Out:
# (1095, 20)

# %%
data['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 144
# Chennai Super Kings            138
# Kolkata Knight Riders          131
# Royal Challengers Bangalore    116
# Rajasthan Royals               112
# Sunrisers Hyderabad             88
# Kings XI Punjab                 88
# Delhi Daredevils                67
# Delhi Capitals                  48
# Deccan Chargers                 29
# Gujarat Titans                  28
# Punjab Kings                    24
# Lucknow Super Giants            24
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Royal Challengers Bengaluru      7
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %%
first=data[data["season"]==2008]["winner"]
first.head()
# Out:
# 0          Kolkata Knight Riders
# 1            Chennai Super Kings
# 2               Delhi Daredevils
# 3    Royal Challengers Bangalore
# 4          Kolkata Knight Riders
# Name: winner, dtype: object

# %%
first.value_counts()
# Out:
# winner
# Rajasthan Royals               13
# Kings XI Punjab                10
# Chennai Super Kings             9
# Delhi Daredevils                7
# Mumbai Indians                  7
# Kolkata Knight Riders           6
# Royal Challengers Bangalore     4
# Deccan Chargers                 2
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.bar(list(first.value_counts().keys()),list(first.value_counts()))
plt.xticks(rotation=90)
plt.show()

# %%
data["target_runs"].value_counts()
# Out:
# target_runs
# 166.0    21
# 172.0    21
# 188.0    20
# 165.0    20
# 163.0    19
#          ..
# 90.0      1
# 267.0     1
# 225.0     1
# 262.0     1
# 242.0     1
# Name: count, Length: 170, dtype: int64

# %%
data["target_runs"].max()
# Out:
# np.float64(288.0)

# %%
data[data["target_runs"]==288]
# Out:
#            id  season       city        date match_type player_of_match  \
# 1053  1426268    2024  Bengaluru  2024-04-15     League         TM Head
#
#                                  venue                team1  \
# 1053  M Chinnaswamy Stadium, Bengaluru  Sunrisers Hyderabad
#
#                             team2                  toss_winner toss_decision  \
# 1053  Royal Challengers Bengaluru  Royal Challengers Bengaluru         field
#
#                    winner result  result_margin  target_runs  target_overs  \
# 1053  Sunrisers Hyderabad   runs           25.0        288.0          20.0
#
#      super_over method       umpire1   umpire2
# 1053          N    NaN  AK Chaudhary  R Pandit

# %%
data[data["season"]==2008]
# Out:
#         id  season        city        date  match_type   player_of_match  \
# 0   335982    2008   Bangalore  2008-04-18      League       BB McCullum
# 1   335983    2008  Chandigarh  2008-04-19      League        MEK Hussey
# 2   335984    2008       Delhi  2008-04-19      League       MF Maharoof
# 3   335985    2008      Mumbai  2008-04-20      League        MV Boucher
# 4   335986    2008     Kolkata  2008-04-20      League         DJ Hussey
# 5   335987    2008      Jaipur  2008-04-21      League         SR Watson
# 6   335988    2008   Hyderabad  2008-04-22      League          V Sehwag
# 7   335989    2008     Chennai  2008-04-23      League         ML Hayden
# 8   335990    2008   Hyderabad  2008-04-24      League         YK Pathan
# 9   335991    2008  Chandigarh  2008-04-25      League     KC Sangakkara
# 10  335992    2008   Bangalore  2008-04-26      League         SR Watson
# 11  335993    2008     Chennai  2008-04-26      League          JDP Oram
# ...

# %%
final=data[data["match_type"]=="Final"]
final
# Out:
#            id  season          city        date match_type player_of_match  \
# 57     336040    2008        Mumbai  2008-06-01      Final       YK Pathan
# 114    392239    2009  Johannesburg  2009-05-24      Final        A Kumble
# 174    419165    2010        Mumbai  2010-04-25      Final        SK Raina
# 247    501271    2011       Chennai  2011-05-28      Final         M Vijay
# 321    548381    2012       Chennai  2012-05-27      Final        MS Bisla
# 397    598073    2013       Kolkata  2013-05-26      Final      KA Pollard
# 457    734049    2014     Bangalore  2014-06-01      Final       MK Pandey
# 516    829823    2015       Kolkata  2015-05-24      Final       RG Sharma
# 576    981019    2016     Bangalore  2016-05-29      Final     BCJ Cutting
# 635   1082650    2017     Hyderabad  2017-05-21      Final       KH Pandya
# 695   1136620    2018        Mumbai  2018-05-27      Final       SR Watson
# ...

# %%
final["winner"].value_counts()
# Out:
# winner
# Chennai Super Kings      5
# Mumbai Indians           5
# Kolkata Knight Riders    3
# Deccan Chargers          1
# Rajasthan Royals         1
# Sunrisers Hyderabad      1
# Gujarat Titans           1
# Name: count, dtype: int64

# %%
plt.bar(list(final["winner"].value_counts().keys()),list(final["winner"].value_counts()))
plt.xticks(rotation=90)
plt.show()

# %%
final=data[data["match_type"]=="Final"]
final
# Out:
#            id  season          city        date match_type player_of_match  \
# 57     336040    2008        Mumbai  2008-06-01      Final       YK Pathan
# 114    392239    2009  Johannesburg  2009-05-24      Final        A Kumble
# 174    419165    2010        Mumbai  2010-04-25      Final        SK Raina
# 247    501271    2011       Chennai  2011-05-28      Final         M Vijay
# 321    548381    2012       Chennai  2012-05-27      Final        MS Bisla
# 397    598073    2013       Kolkata  2013-05-26      Final      KA Pollard
# 457    734049    2014     Bangalore  2014-06-01      Final       MK Pandey
# 516    829823    2015       Kolkata  2015-05-24      Final       RG Sharma
# 576    981019    2016     Bangalore  2016-05-29      Final     BCJ Cutting
# 635   1082650    2017     Hyderabad  2017-05-21      Final       KH Pandya
# 695   1136620    2018        Mumbai  2018-05-27      Final       SR Watson
# ...

# %%
final["winner"].value_counts()
# Out:
# winner
# Chennai Super Kings      5
# Mumbai Indians           5
# Kolkata Knight Riders    3
# Deccan Chargers          1
# Rajasthan Royals         1
# Sunrisers Hyderabad      1
# Gujarat Titans           1
# Name: count, dtype: int64

# %%
final_winners = final.groupby("season").last()[["winner"]]
final_winners
# Out:
#                        winner
# season
# 2008         Rajasthan Royals
# 2009          Deccan Chargers
# 2010      Chennai Super Kings
# 2011      Chennai Super Kings
# 2012    Kolkata Knight Riders
# 2013           Mumbai Indians
# 2014    Kolkata Knight Riders
# 2015           Mumbai Indians
# 2016      Sunrisers Hyderabad
# 2017           Mumbai Indians
# 2018      Chennai Super Kings
# 2019           Mumbai Indians
# 2020           Mumbai Indians
# 2021      Chennai Super Kings
# 2022           Gujarat Titans
# 2023      Chennai Super Kings
# 2024    Kolkata Knight Riders

# %%
plt.hist(final_winners)
plt.xticks(rotation=90)
plt.show()

# %%
final["player_of_match"].value_counts()
# Out:
# player_of_match
# YK Pathan       1
# A Kumble        1
# SK Raina        1
# M Vijay         1
# MS Bisla        1
# KA Pollard      1
# MK Pandey       1
# RG Sharma       1
# BCJ Cutting     1
# KH Pandya       1
# SR Watson       1
# JJ Bumrah       1
# TA Boult        1
# F du Plessis    1
# HH Pandya       1
# DP Conway       1
# MA Starc        1
# Name: count, dtype: int64

# %%
data.head()
# Out:
#        id  season        city        date match_type player_of_match  \
# 0  335982    2008   Bangalore  2008-04-18     League     BB McCullum
# 1  335983    2008  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984    2008       Delhi  2008-04-19     League     MF Maharoof
# 3  335985    2008      Mumbai  2008-04-20     League      MV Boucher
# 4  335986    2008     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
player_of_match=data['player_of_match'].value_counts()
player_of_match.head(20)
# Out:
# player_of_match
# AB de Villiers    25
# CH Gayle          22
# RG Sharma         19
# DA Warner         18
# V Kohli           18
# MS Dhoni          17
# SR Watson         16
# YK Pathan         16
# RA Jadeja         16
# AD Russell        15
# SP Narine         15
# KA Pollard        14
# SK Raina          14
# JC Buttler        13
# AM Rahane         13
# KL Rahul          13
# G Gambhir         13
# S Dhawan          12
# MEK Hussey        12
# A Mishra          12
# Name: count, dtype: int64

# %%
plt.bar(list(player_of_match[0:10].keys()),list(player_of_match[0:10]))
plt.xticks(rotation=90)
# plt.hist(player_of_match)
plt.show()

# %%
superover=data[data["super_over"]=="Y"]
superover
# Out:
#           id  season       city        date match_type player_of_match  \
# 66    392190    2009  Cape Town  2009-04-23     League       YK Pathan
# 130   419121    2010    Chennai  2010-03-21     League        J Theron
# 328   598004    2013  Hyderabad  2013-04-07     League       GH Vihari
# 342   598017    2013  Bangalore  2013-04-16     League         V Kohli
# 416   729315    2014  Abu Dhabi  2014-04-29     League     JP Faulkner
# 475   829741    2015  Ahmedabad  2015-04-21     League        SE Marsh
# 610  1082625    2017     Rajkot  2017-04-29     League       KH Pandya
# 705  1175365    2019      Delhi  2019-03-30     League         PP Shaw
# 746  1178426    2019     Mumbai  2019-05-02     League       JJ Bumrah
# 757  1216493    2020        NaN  2020-09-20     League      MP Stoinis
# 765  1216547    2020        NaN  2020-09-28     League  AB de Villiers
# 790  1216512    2020  Abu Dhabi  2020-10-18     League     LH Ferguson
# ...

# %%
team_wins = final["winner"].value_counts()
winner=team_wins.idxmax()
print("2025 Winner : " + winner )
# Out:
# 2025 Winner : Chennai Super Kings

# %%
play=data["player_of_match"].value_counts()
player_of_match=play.idxmax()
print(player_of_match)
# Out:
# AB de Villiers

# %%
data["city"].value_counts()
# Out:
# city
# Mumbai            173
# Kolkata            93
# Delhi              90
# Chennai            85
# Hyderabad          77
# Bangalore          65
# Chandigarh         61
# Jaipur             57
# Pune               51
# Abu Dhabi          37
# Ahmedabad          36
# Bengaluru          29
# Visakhapatnam      15
# Durban             15
# Lucknow            14
# Dubai              13
# Dharamsala         13
# Centurion          12
# Rajkot             10
# Sharjah            10
# Navi Mumbai         9
# Indore              9
# Johannesburg        8
# Ranchi              7
# Cuttack             7
# Cape Town           7
# Port Elizabeth      7
# Raipur              6
# Kochi               5
# Mohali              5
# Kanpur              4
# East London         3
# Kimberley           3
# Nagpur              3
# Guwahati            3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
final_city=final["city"].value_counts()
final_city
# Out:
# city
# Mumbai          3
# Chennai         3
# Kolkata         2
# Bangalore       2
# Ahmedabad       2
# Hyderabad       2
# Johannesburg    1
# Dubai           1
# Name: count, dtype: int64

# %%
plt.bar(list(final_city.keys()),list(final_city))
plt.xticks(rotation=90)
plt.show()
